# %% [markdown]
# <a href="https://colab.research.google.com/github/boraacer/ICA-PCA/blob/main/ICA_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy as sp
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# !pip install --upgrade openpyxl

# !wget -O data_ecg.xlsx 'https://github.com/boraacer/ICA-PCA/raw/main/ecg_data.xlsx'

df = pd.read_excel(r'data_ecg.xlsx', engine='openpyxl', names=['Channel 1', 'Channel 2', 'Channel 3'])
print(df)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# --2023-06-26 12:30:36--  https://github.com/boraacer/ICA-PCA/raw/main/ecg_data.xlsx
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/boraacer/ICA-PCA/main/ecg_data.xlsx [following]
# --2023-06-26 12:30:36--  https://raw.githubusercontent.com/boraacer/ICA-PCA/main/ecg_data.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101461 (99K) [application/octet-stream]
# Saving to: ‘data_ecg.xlsx’
#
# data_ecg.xlsx       100%[===================>]  99.08K  --.-KB/s    in 0.002s
#
# ...

# %%
df.set_index('Channel 1').plot()
plt.show()
